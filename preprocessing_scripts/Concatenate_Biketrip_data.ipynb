# %%
import pandas as pd 

#Add File Prefix for Blue Bike Trip Data
prefix = '../Data/BlueBikesData/'

files = [
    '202304-bluebikes-tripdata.csv',
    '202307-bluebikes-tripdata.csv',
    '202310-bluebikes-tripdata.csv',
    '202312-bluebikes-tripdata.csv'
]

# Read each file and store them in a list
dataframes = [pd.read_csv(prefix + file) for file in files]

# Add season column for each dataframe
dataframes[0]['season'] = 'spring'
dataframes[1]['season'] = 'summer'
dataframes[2]['season'] = 'fall'
dataframes[3]['season'] = 'winter'

# %%
# Concatenate dataframes
trip_data_2023 = pd.concat(dataframes, ignore_index=True, axis = 0)

# %%
trip_data_2023.shape
# Out:
# (1313047, 14)

# %%
# Check null values
trip_data_2023.isnull().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name       8
# start_station_id         8
# end_station_name      7343
# end_station_id        7343
# start_lat                0
# start_lng                0
# end_lat               7264
# end_lng               7264
# member_casual            0
# season                   0
# dtype: int64

# %%
# Drop null rows (only a handful)
trip_data_2023 = trip_data_2023.dropna()

# %%
import numpy as np

# Haversine function to compute distance from start to end station
def haversine(lat1, lon1, lat2, lon2):
    """
    Calculate the great circle distance in miles between two points 
    on the earth (specified in decimal degrees)
    """
    
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    dlat = lat2 - lat1 
    dlon = lon2 - lon1 
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a)) 
    r = 3956 
    return c * r

# %%
trip_data_2023
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        0093AA5E7E3E0158    docked_bike  2023-04-13 13:49:59
# 1        BFA8B88E063688F4    docked_bike  2023-04-25 09:44:38
# 2        A9C51FA200C31A81    docked_bike  2023-04-24 18:39:31
# 3        0C1D451797FF0871    docked_bike  2023-04-04 19:25:31
# 4        DDDCD0A2D2EE7A37    docked_bike  2023-04-11 08:36:14
# ...                   ...            ...                  ...
# 1313042  4079F85781F2FB07   classic_bike  2023-12-20 08:22:55
# 1313043  A2411C8176C88993   classic_bike  2023-12-13 08:22:31
# 1313044  C3D217A504FC1222   classic_bike  2023-12-05 22:10:12
# 1313045  105A4D5A6FB5CE19   classic_bike  2023-12-23 12:16:56
# 1313046  F55AD190FE0B57EC  electric_bike  2023-12-21 16:14:16
#
#                     ended_at                              start_station_name  \
# 0        2023-04-13 13:55:04  Innovation Lab - 125 Western Ave at Batten Way
# 1        2023-04-25 09:51:28                               Museum of Science
# 2        2023-04-24 18:58:05                       New Balance - 20 Guest St
# 3        2023-04-04 19:32:14                               Museum of Science
# 4        2023-04-11 08:52:39                               Museum of Science
# ...                      ...                                             ...
# 1313042  2023-12-20 08:41:17                               Lesley University
# 1313043  2023-12-13 08:39:35                               Lesley University
# 1313044  2023-12-05 22:35:39                 Congress St at Boston City Hall
# 1313045  2023-12-23 12:41:35                               Lesley University
# 1313046  2023-12-21 16:36:19                               Lesley University
#
#         start_station_id                                 end_station_name  \
# 0                 A32011            Soldiers Field Park - 111 Western Ave
# 1                 M32045    One Broadway / Kendall Sq at Main St / 3rd St
# 2                 D32001  HMS/HSPH - Avenue Louis Pasteur at Longwood Ave
# 3                 M32045                    Gore Street at Lambert Street
# 4                 M32045                     Columbus Ave at W. Canton St
# ...                  ...                                              ...
# 1313042           M32039                            EF - North Point Park
# 1313043           M32039                            EF - North Point Park
# 1313044           D32009                                    MIT Vassar St
# 1313045           M32039                                    MIT Vassar St
# 1313046           M32039                        Riverway at Brookline Ave
#
#         end_station_id  start_lat  start_lng    end_lat    end_lng  \
# 0               A32006  42.363713 -71.124598  42.364263 -71.118276
# 1               M32003  42.367690 -71.071163  42.362242 -71.083111
# 2               B32003  42.357329 -71.146735  42.337417 -71.102861
# 3               M32081  42.367690 -71.071163  42.373080 -71.086342
# 4               C32077  42.367690 -71.071163  42.344742 -71.076482
# ...                ...        ...        ...        ...        ...
# 1313042         M32034  42.386748 -71.119019  42.369885 -71.069957
# 1313043         M32034  42.386748 -71.119019  42.369885 -71.069957
# 1313044         M32042  42.360417 -71.057522  42.355601 -71.103945
# 1313045         M32042  42.386748 -71.119019  42.355601 -71.103945
# 1313046         A32056  42.386466 -71.119073  42.336610 -71.110047
#
#         member_casual  season
# 0              member  spring
# 1              member  spring
# 2              casual  spring
# 3              member  spring
# 4              member  spring
# ...               ...     ...
# 1313042        member  winter
# 1313043        member  winter
# 1313044        casual  winter
# 1313045        member  winter
# 1313046        member  winter
#
# [1305701 rows x 14 columns]

# %%
# Compute distance of each bike trip
trip_data_2023['trip_distance'] = trip_data_2023.apply(lambda row: haversine(row['start_lat'], row['start_lng'], row['end_lat'], row['end_lng']), axis=1)

# %%
trip_data_2023.describe()
# Out:
#           start_lat     start_lng       end_lat       end_lng  trip_distance
# count  1.305701e+06  1.305701e+06  1.305701e+06  1.305701e+06   1.305701e+06
# mean   4.235940e+01 -7.109001e+01  4.235933e+01 -7.108972e+01   1.236565e+00
# std    2.066682e-02  2.952048e-02  2.068335e-02  2.957417e-02   8.813457e-01
# min    4.216723e+01 -7.124776e+01  4.216723e+01 -7.124776e+01   0.000000e+00
# 25%    4.234871e+01 -7.110734e+01  4.234871e+01 -7.110729e+01   6.231077e-01
# 50%    4.235957e+01 -7.109116e+01  4.235957e+01 -7.109051e+01   1.025209e+00
# 75%    4.236895e+01 -7.107119e+01  4.236895e+01 -7.107119e+01   1.653843e+00
# max    4.253467e+01 -7.087021e+01  4.253467e+01 -7.087021e+01   1.562984e+01

# %%
trip_data_2023.isnull().sum()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# season                0
# trip_distance         0
# dtype: int64

# %%
trip_data_2023.to_csv("../Data/BlueBikesData/trips_data_2023.csv")
